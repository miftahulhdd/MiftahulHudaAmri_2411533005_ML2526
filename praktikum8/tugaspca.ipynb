# %% [markdown]
# <a href="https://colab.research.google.com/github/miftahulhdd/MiftahulHudaAmri_2411533005_ML2526/blob/main/praktikum8/tugaspca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = load_breast_cancer()

X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

print("Shape data:", X.shape)
# Out:
# Shape data: (569, 30)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca_80 = PCA(n_components=0.80)
X_pca_80 = pca_80.fit_transform(X_scaled)

pca_90 = PCA(n_components=0.90)
X_pca_90 = pca_90.fit_transform(X_scaled)

pca_95 = PCA(n_components=0.95)
X_pca_95 = pca_95.fit_transform(X_scaled)

print("Jumlah komponen untuk 80% variance:", pca_80.n_components_)
print("Jumlah komponen untuk 90% variance:", pca_90.n_components_)
print("Jumlah komponen untuk 95% variance:", pca_95.n_components_)
# Out:
# Jumlah komponen untuk 80% variance: 5
# Jumlah komponen untuk 90% variance: 7
# Jumlah komponen untuk 95% variance: 10

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)
print(accuracy_score(y_test, y_pred))

# %%
pca_2 = PCA(n_components=2)
X_train_pca2 = pca_2.fit_transform(x_train)
X_test_pca2 = pca_2.transform(x_test)
lr_pca2 = LogisticRegression()
lr_pca2.fit(X_train_pca2, y_train)
y_pred_pca2 = lr_pca2.predict(x_test_pca2)
print(accuracy_score(y_test, y_pred_pca2))

# %%
model_logreg = LogisticRegression(max_iter=5000)

model_logreg.fit(X_train, y_train)

y_pred_logreg = model_logreg.predict(X_test)

acc_logreg = accuracy_score(y_test, y_pred_logreg)

print("Akurasi tanpa PCA:", acc_logreg)
# Out:
# Akurasi tanpa PCA: 0.9736842105263158

# %%
# PCA 2 komponen

pca_2 = PCA(n_components=2)

X_pca_2 = pca_2.fit_transform(X_scaled)

print("Shape PCA 2 komponen:", X_pca_2.shape)
# Out:
# Shape PCA 2 komponen: (569, 2)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_pca_2,
    y,
    test_size=0.2,
    random_state=42
)

model_pca_2 = LogisticRegression(max_iter=5000)

model_pca_2.fit(X_train, y_train)

y_pred_pca_2 = model_pca_2.predict(X_test)

acc_pca_2 = accuracy_score(y_test, y_pred_pca_2)

print("Akurasi PCA 2 komponen:", acc_pca_2)
# Out:
# Akurasi PCA 2 komponen: 0.9912280701754386

# %%
# PCA 10 Komponen

pca_10 = PCA(n_components=10)

X_pca_10 = pca_10.fit_transform(X_scaled)

print("Shape PCA 10 komponen:", X_pca_10.shape)
# Out:
# Shape PCA 10 komponen: (569, 10)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_pca_10,
    y,
    test_size=0.2,
    random_state=42
)

model_pca_10 = LogisticRegression(max_iter=5000)

model_pca_10.fit(X_train, y_train)

y_pred_pca_10 = model_pca_10.predict(X_test)

acc_pca_10 = accuracy_score(y_test, y_pred_pca_10)

print("Akurasi PCA 10 komponen:", acc_pca_10)
# Out:
# Akurasi PCA 10 komponen: 0.9824561403508771
